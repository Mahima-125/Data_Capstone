# %%
# %sql
USE CATALOG catalogus6;
CREATE SCHEMA schema1;

# %%
# %sql
CREATE TABLE my_table (
    id INT,
    name STRING
);

# %%
data = [(1, "Alice"), (2, "Bob")]
df = spark.createDataFrame(data, ["id", "name"])
#df.write.saveAsTable("my_table")

# %%
# %sql
INSERT INTO my_table VALUES (1, "Alice"), (2, "Bob"),(3, 'Charlie');

# %%
# %sql
SELECT * FROM my_table;

# %%
# %sql
CREATE VIEW my_view AS SELECT name FROM my_table WHERE id > 1;

# %%
# %sql
GRANT SELECT ON TABLE my_table TO `user6@sscloudtse.onmicrosoft.com`;

# %%
# %sql
SHOW GRANTS ON TABLE my_table;
